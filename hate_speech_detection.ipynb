# %%
import pandas as pd
import numpy as np
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\e786h\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopword = set(stopwords.words('english'))
stemmer = SnowballStemmer("english")

# %%
data = pd.read_csv("twitter_data.csv")
print(data.head())
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
data["labels"] = data["class"].map({0: "Hate Speech", 1: "Offensive Speech", 2: "No Hate and Offensive Speech"})
data = data[["tweet", "labels"]]
print("\nDataset after adding labels column and filtering necessary columns:")
print(data.head())
# Out:
# Dataset after adding labels column and filtering necessary columns:
#                                                tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                          labels
# 0  No Hate and Offensive Speech
# 1              Offensive Speech
# 2              Offensive Speech
# 3              Offensive Speech
# 4              Offensive Speech

# %%
def clean(text):
    text = str(text).lower()
    text = re.sub(r'[.?]', '', text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w\d\w', '', text)
    text = [word for word in text.split() if word not in stopword]
    text = " ".join(text)
    text = [stemmer.stem(word) for word in text.split()]
    text = " ".join(text)
    return text

# %%
data["tweet"] = data["tweet"].apply(clean)
print("\nSample cleaned tweets:")
print(data["tweet"].head())
# Out:
# Sample cleaned tweets:
# 0    rt mayasolov woman shouldnt complain clean hou...
# 1    rt mlee boy dat coldtyga dwn bad cuffin dat ho...
# 2    rt urkindofbrand dawg rt babif ever fuck bitch...
# 3                rt cganderson vivaba look like tranni
# 4    rt shenikarobert shit hear might true might fa...
# Name: tweet, dtype: object

# %%
x = np.array(data["tweet"])
y = np.array(data["labels"])


cv = CountVectorizer()
X = cv.fit_transform(x)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = DecisionTreeClassifier()

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy of the model: {accuracy}")
# Out:
# Accuracy of the model: 0.8783469861841301

# %%
# Re-import CountVectorizer if it is not already imported
from sklearn.feature_extraction.text import CountVectorizer

# Ensure CountVectorizer is initialized and fitted before transforming input
if 'cv' not in globals():
    print("Reinitializing CountVectorizer...")
    cv = CountVectorizer()
    cv.fit(x)  # Fit with the original dataset

# Test the model with a custom input
inp = "You are too bad and I don't like your attitude"

# Preprocess and transform the input
inp_transformed = cv.transform([inp]).toarray()

# Make and display the prediction
prediction = model.predict(inp_transformed)
print(f"\nPrediction for input '{inp}': {prediction}")
# Out:
# Reinitializing CountVectorizer...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       6     print("Reinitializing CountVectorizer...")
#       7     cv = CountVectorizer()
# ----> 8     cv.fit(x)  # Fit with the original dataset
#      10 # Test the model with a custom input
#      11 inp = "You are too bad and I don't like your attitude"
#
# NameError: name 'x' is not defined
